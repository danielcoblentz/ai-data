# %%
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-83679b5ac97b> in <cell line: 49>()
#      47
#      48 # Load the training dataset with data augmentation
# ---> 49 train_dataset_augmented = data_augmentation.flow_from_directory(
#      50     directory=data_dir,            # Path to the main dataset directory
#      51     target_size=(227, 227),         # Resize images to 227x227 pixels (AlexNet input size)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
# ...
